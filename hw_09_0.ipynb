# %% [markdown]
# # hw_9

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
num_classes = 10
num_features = 28 * 28 * 1
learning_rate = 0.001
batch_size = 256
epochs = 120


x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)
x_train, x_test = x_train.reshape([-1, num_features]), x_test.reshape([-1, num_features])
x_train, x_test = x_train / 255., x_test / 255.

train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.repeat().shuffle(5000).batch(batch_size).prefetch(1)


model = Sequential([
    Flatten(input_shape=(num_features,)),
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(512, activation='relu'),
    Dropout(0.4),
    Dense(512, activation='relu'),
    Dropout(0.4),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, restore_best_weights=True)

lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1)

model.compile(optimizer=Adam(learning_rate=learning_rate),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

steps_per_epoch = len(x_train) // batch_size

callbacks = [lr_scheduler, early_stopping]

history = model.fit(train_data,
                    epochs=epochs,
                    batch_size=batch_size,
                    steps_per_epoch=steps_per_epoch,
                    validation_data=(x_test, y_test),
                    callbacks=callbacks
                    )

train_loss, train_acc = model.evaluate(x_train, y_train)
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\nTrain accuracy: {train_acc:.4f}")
print(f"Test accuracy: {test_acc:.4f}")
print(f"Difference accuracy: {(train_acc - test_acc)*100:.2f}%")
# Out:
# Epoch 1/120
# 234/234 [==============================] - 4s 6ms/step - loss: 0.7551 - accuracy: 0.7148 - val_loss: 0.4611 - val_accuracy: 0.8288 - lr: 0.0010
# Epoch 2/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.4902 - accuracy: 0.8244 - val_loss: 0.4207 - val_accuracy: 0.8464 - lr: 0.0010
# Epoch 3/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.4478 - accuracy: 0.8393 - val_loss: 0.4050 - val_accuracy: 0.8513 - lr: 0.0010
# Epoch 4/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.4236 - accuracy: 0.8470 - val_loss: 0.3833 - val_accuracy: 0.8621 - lr: 0.0010
# Epoch 5/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.4032 - accuracy: 0.8543 - val_loss: 0.3831 - val_accuracy: 0.8625 - lr: 0.0010
# Epoch 6/120
# 234/234 [==============================] - 2s 6ms/step - loss: 0.3925 - accuracy: 0.8584 - val_loss: 0.3794 - val_accuracy: 0.8641 - lr: 0.0010
# Epoch 7/120
# 234/234 [==============================] - 2s 7ms/step - loss: 0.3803 - accuracy: 0.8631 - val_loss: 0.3899 - val_accuracy: 0.8535 - lr: 0.0010
# Epoch 8/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.3678 - accuracy: 0.8669 - val_loss: 0.3579 - val_accuracy: 0.8676 - lr: 0.0010
# Epoch 9/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.3636 - accuracy: 0.8681 - val_loss: 0.3549 - val_accuracy: 0.8718 - lr: 0.0010
# Epoch 10/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.3577 - accuracy: 0.8707 - val_loss: 0.3439 - val_accuracy: 0.8766 - lr: 0.0010
# Epoch 11/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.3498 - accuracy: 0.8737 - val_loss: 0.3574 - val_accuracy: 0.8721 - lr: 0.0010
# Epoch 12/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.3425 - accuracy: 0.8749 - val_loss: 0.3426 - val_accuracy: 0.8726 - lr: 0.0010
# Epoch 13/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.3366 - accuracy: 0.8782 - val_loss: 0.3327 - val_accuracy: 0.8807 - lr: 0.0010
# Epoch 14/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.3349 - accuracy: 0.8786 - val_loss: 0.3404 - val_accuracy: 0.8754 - lr: 0.0010
# Epoch 15/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2705 - accuracy: 0.9007 - val_loss: 0.3109 - val_accuracy: 0.8907 - lr: 0.0010
# Epoch 41/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2478 - accuracy: 0.9097 - val_loss: 0.3052 - val_accuracy: 0.8960 - lr: 5.0000e-04
# Epoch 42/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2389 - accuracy: 0.9120 - val_loss: 0.3001 - val_accuracy: 0.8963 - lr: 5.0000e-04
# Epoch 43/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.2398 - accuracy: 0.9107 - val_loss: 0.2995 - val_accuracy: 0.8956 - lr: 5.0000e-04
# Epoch 44/120
# 234/234 [==============================] - 2s 7ms/step - loss: 0.2342 - accuracy: 0.9133 - val_loss: 0.2979 - val_accuracy: 0.8949 - lr: 5.0000e-04
# Epoch 45/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2316 - accuracy: 0.9140 - val_loss: 0.2998 - val_accuracy: 0.8939 - lr: 5.0000e-04
# Epoch 46/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2303 - accuracy: 0.9140 - val_loss: 0.3016 - val_accuracy: 0.8978 - lr: 5.0000e-04
# Epoch 47/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2269 - accuracy: 0.9156 - val_loss: 0.2977 - val_accuracy: 0.8973 - lr: 5.0000e-04
# Epoch 48/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2267 - accuracy: 0.9157 - val_loss: 0.3027 - val_accuracy: 0.8938 - lr: 5.0000e-04
# Epoch 49/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2253 - accuracy: 0.9161 - val_loss: 0.2962 - val_accuracy: 0.8968 - lr: 5.0000e-04
# Epoch 50/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2237 - accuracy: 0.9169 - val_loss: 0.3064 - val_accuracy: 0.8930 - lr: 5.0000e-04
# Epoch 51/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2223 - accuracy: 0.9166 - val_loss: 0.2967 - val_accuracy: 0.8981 - lr: 5.0000e-04
# Epoch 52/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2186 - accuracy: 0.9177 - val_loss: 0.2993 - val_accuracy: 0.8968 - lr: 5.0000e-04
# Epoch 53/120
# 234/234 [==============================] - 2s 7ms/step - loss: 0.2172 - accuracy: 0.9195 - val_loss: 0.3001 - val_accuracy: 0.8971 - lr: 5.0000e-04
# Epoch 54/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.2170 - accuracy: 0.9185 - val_loss: 0.3014 - val_accuracy: 0.8993 - lr: 5.0000e-04
# Epoch 55/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.2191 - accuracy: 0.9194 - val_loss: 0.3004 - val_accuracy: 0.8977 - lr: 5.0000e-04
# Epoch 56/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2153 - accuracy: 0.9202 - val_loss: 0.3023 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 57/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2154 - accuracy: 0.9205 - val_loss: 0.3033 - val_accuracy: 0.8984 - lr: 5.0000e-04
# Epoch 58/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2120 - accuracy: 0.9210 - val_loss: 0.3048 - val_accuracy: 0.9001 - lr: 5.0000e-04
# Epoch 59/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.2118 - accuracy: 0.9207 - val_loss: 0.3024 - val_accuracy: 0.8984 - lr: 5.0000e-04
# Epoch 60/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2093 - accuracy: 0.9203 - val_loss: 0.3052 - val_accuracy: 0.8991 - lr: 5.0000e-04
# Epoch 61/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.2105 - accuracy: 0.9211 - val_loss: 0.3042 - val_accuracy: 0.8970 - lr: 5.0000e-04
# Epoch 62/120
# 234/234 [==============================] - 2s 7ms/step - loss: 0.2113 - accuracy: 0.9211 - val_loss: 0.3084 - val_accuracy: 0.8950 - lr: 5.0000e-04
# Epoch 63/120
# 230/234 [============================>.] - ETA: 0s - loss: 0.2088 - accuracy: 0.9229
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 234/234 [==============================] - 2s 7ms/step - loss: 0.2089 - accuracy: 0.9229 - val_loss: 0.3015 - val_accuracy: 0.8989 - lr: 5.0000e-04
# Epoch 64/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.1957 - accuracy: 0.9264 - val_loss: 0.3033 - val_accuracy: 0.9008 - lr: 2.5000e-04
# Epoch 65/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.1917 - accuracy: 0.9286 - val_loss: 0.3044 - val_accuracy: 0.9006 - lr: 2.5000e-04
# Epoch 66/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.1906 - accuracy: 0.9286 - val_loss: 0.3047 - val_accuracy: 0.9002 - lr: 2.5000e-04
# Epoch 67/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.1907 - accuracy: 0.9281 - val_loss: 0.3074 - val_accuracy: 0.9020 - lr: 2.5000e-04
# Epoch 68/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1879 - accuracy: 0.9296 - val_loss: 0.3048 - val_accuracy: 0.9011 - lr: 2.5000e-04
# Epoch 69/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1868 - accuracy: 0.9295 - val_loss: 0.3073 - val_accuracy: 0.9020 - lr: 2.5000e-04
# Epoch 70/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1860 - accuracy: 0.9300 - val_loss: 0.3051 - val_accuracy: 0.9001 - lr: 2.5000e-04
# Epoch 71/120
# 234/234 [==============================] - 2s 7ms/step - loss: 0.1829 - accuracy: 0.9313 - val_loss: 0.3112 - val_accuracy: 0.8994 - lr: 2.5000e-04
# Epoch 72/120
# 234/234 [==============================] - 2s 7ms/step - loss: 0.1817 - accuracy: 0.9319 - val_loss: 0.3124 - val_accuracy: 0.9022 - lr: 2.5000e-04
# Epoch 73/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.1850 - accuracy: 0.9308 - val_loss: 0.3059 - val_accuracy: 0.9018 - lr: 2.5000e-04
# Epoch 74/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1811 - accuracy: 0.9323 - val_loss: 0.3089 - val_accuracy: 0.9000 - lr: 2.5000e-04
# Epoch 75/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1821 - accuracy: 0.9314 - val_loss: 0.3029 - val_accuracy: 0.9010 - lr: 2.5000e-04
# Epoch 76/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1803 - accuracy: 0.9323 - val_loss: 0.3107 - val_accuracy: 0.9010 - lr: 2.5000e-04
# Epoch 77/120
# 231/234 [============================>.] - ETA: 0s - loss: 0.1777 - accuracy: 0.9336
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1777 - accuracy: 0.9335 - val_loss: 0.3100 - val_accuracy: 0.9012 - lr: 2.5000e-04
# Epoch 78/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1732 - accuracy: 0.9353 - val_loss: 0.3108 - val_accuracy: 0.9018 - lr: 1.2500e-04
# Epoch 79/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1702 - accuracy: 0.9355 - val_loss: 0.3116 - val_accuracy: 0.9016 - lr: 1.2500e-04
# Epoch 80/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.1706 - accuracy: 0.9360 - val_loss: 0.3089 - val_accuracy: 0.9010 - lr: 1.2500e-04
# Epoch 81/120
# 234/234 [==============================] - 2s 7ms/step - loss: 0.1697 - accuracy: 0.9354 - val_loss: 0.3106 - val_accuracy: 0.9020 - lr: 1.2500e-04
# Epoch 82/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1682 - accuracy: 0.9366 - val_loss: 0.3148 - val_accuracy: 0.9027 - lr: 1.2500e-04
# Epoch 83/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1700 - accuracy: 0.9354 - val_loss: 0.3118 - val_accuracy: 0.9031 - lr: 1.2500e-04
# Epoch 84/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1686 - accuracy: 0.9368 - val_loss: 0.3126 - val_accuracy: 0.9036 - lr: 1.2500e-04
# Epoch 85/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1641 - accuracy: 0.9381 - val_loss: 0.3108 - val_accuracy: 0.9053 - lr: 1.2500e-04
# Epoch 86/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1675 - accuracy: 0.9369 - val_loss: 0.3174 - val_accuracy: 0.9012 - lr: 1.2500e-04
# Epoch 87/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1645 - accuracy: 0.9376 - val_loss: 0.3213 - val_accuracy: 0.9011 - lr: 1.2500e-04
# Epoch 88/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1647 - accuracy: 0.9376 - val_loss: 0.3159 - val_accuracy: 0.9021 - lr: 1.2500e-04
# Epoch 89/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.1655 - accuracy: 0.9374 - val_loss: 0.3211 - val_accuracy: 0.9018 - lr: 1.2500e-04
# Epoch 90/120
# 228/234 [============================>.] - ETA: 0s - loss: 0.1626 - accuracy: 0.9398
# Epoch 90: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 234/234 [==============================] - 2s 7ms/step - loss: 0.1628 - accuracy: 0.9397 - val_loss: 0.3172 - val_accuracy: 0.9016 - lr: 1.2500e-04
# Epoch 91/120
# 234/234 [==============================] - 1s 6ms/step - loss: 0.1616 - accuracy: 0.9387 - val_loss: 0.3181 - val_accuracy: 0.9026 - lr: 6.2500e-05
# Epoch 92/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1580 - accuracy: 0.9409 - val_loss: 0.3229 - val_accuracy: 0.9015 - lr: 6.2500e-05
# Epoch 93/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1599 - accuracy: 0.9397 - val_loss: 0.3245 - val_accuracy: 0.9029 - lr: 6.2500e-05
# Epoch 94/120
# 234/234 [==============================] - 1s 5ms/step - loss: 0.1571 - accuracy: 0.9399 - val_loss: 0.3246 - val_accuracy: 0.9022 - lr: 6.2500e-05
# Epoch 95/120
# 233/234 [============================>.] - ETA: 0s - loss: 0.1575 - accuracy: 0.9407
# Epoch 95: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Restoring model weights from the end of the best epoch: 85.
# 234/234 [==============================] - 1s 6ms/step - loss: 0.1579 - accuracy: 0.9406 - val_loss: 0.3243 - val_accuracy: 0.9024 - lr: 6.2500e-05
# Epoch 95: early stopping
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1231 - accuracy: 0.9553
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3108 - accuracy: 0.9053
#
# Train accuracy: 0.9553
# Test accuracy: 0.9053
# Difference accuracy: 5.00%

# %%
from sklearn.metrics import classification_report

# Отримання прогнозованих міток для тестового набору
predicted_probabilities = model.predict(x_test)
predicted_labels = np.argmax(predicted_probabilities, axis=1)

# Звіт про класифікацію
report = classification_report(y_test, predicted_labels, target_names=class_names)
print(report)
# Out:
# 313/313 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.85      0.86      0.86      1000
#      Trouser       0.99      0.99      0.99      1000
#     Pullover       0.81      0.86      0.83      1000
#        Dress       0.89      0.92      0.90      1000
#         Coat       0.85      0.81      0.83      1000
#       Sandal       0.99      0.98      0.98      1000
#        Shirt       0.76      0.72      0.74      1000
#      Sneaker       0.95      0.98      0.96      1000
#          Bag       0.99      0.98      0.98      1000
#   Ankle boot       0.98      0.96      0.97      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.90     10000
# weighted avg       0.91      0.91      0.90     10000

# %%
# Імпортуйте бібліотеку для візуалізації даних
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.grid()

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.grid()

plt.tight_layout()
plt.show()
