# %% [markdown]
# # **Візуалізація даних**

# %% [markdown]
# ## **Matplotlib**

# %% [markdown]
# ### **Лінійні графіки**

# %% [markdown]
# ### **Налаштування графіків**
#
# | Менімонічне значення | Текстове значення | Опис |
# | --- | --- | --- |
# | - | solid | Безперервна лінія |
# | -- | dashed | Штрихова лінія |
# | -. | dashdot | Штрихпунктирна лінія |
# | : | dotted | Пунктирна лінія |
# | None | пробіл або порожній рядок | Не відображати лінію |
#
# | Код | Маркер | Опис |
# | --- | --- | --- |
# | . | . | Крапка |
# | o | ○ | Круг |
# | + | + | Знак плюс |
# | x | × | Хрестик |
# | D | ◇ | Ромб |
# | v | ▽ | Трикутник вершиною вниз |
# | ^ | △ | Трикутник вершиною вгору |
# | s | □ | Квадрат |
# | * | ✭ | Зірка (п'ятикутна) |

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.figure(figsize=(15, 8))
plt.plot(np.arange(1,9), [23, 17, 17, 16, 15, 14, 17, 20],
         label='day temperature',
         linestyle="--",
         color="#FF5733",
         linewidth=2,
         marker="X"
         )

plt.ylim(13, 24)
plt.xlim(1, 10)
plt.xlabel('Дата', fontsize=14, color='midnightblue')
plt.ylabel('Температура, $C^0$', fontsize=14, color='midnightblue')
plt.yticks(np.arange(13,25), np.arange(13,25), rotation=45)
plt.xticks(np.arange(1,9), ["x1", "x2", "x3", "x4", "x5", "x6", "x7", "x8"] , rotation=45)
plt.title('Температура в м. Полтава', fontsize=15)
plt.text(1, 15, 'Осінь досить тепла', color="blue")
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# ### **Компонування графіків**

# %%
fig, axs = plt.subplots(1, 1, figsize=(10, 5))

axs.plot(np.arange(1,9), [23, 17, 17, 16, 15, 14, 17, 20], label='day temperature')
axs.plot(np.arange(1,9), [19, 11, 16, 11, 10, 10, 11, 16], label='night temperature')
plt.xlabel('Дата', fontsize='small', color='midnightblue')
plt.ylabel('Температура', fontsize='small', color='midnightblue')
plt.title('Температура в м. Полтава', fontsize=15)
plt.legend()
plt.grid()
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(10, 5), sharey=True, sharex=True)

axs[0,0].plot(np.arange(1,9), [23, 17, 17, 16, 15, 14, 17, 20], label='day temperature')
axs[0,1].plot(np.arange(1,9), [19, 11, 16, 11, 10, 10, 11, 16], label='night temperature')

axs[0,0].grid()
axs[0,1].grid()

axs[0,0].set_title('Денна', fontsize=10)
axs[0,1].set_title('Нічна', fontsize=10)

fig.suptitle('Температура в м. Полтава', fontsize=15)

plt.show()

# %% [markdown]
# ### **Стовпчикові діаграми**
#
# | Аргумент | Опис |
# | --- | --- |
# | width | Ширина стовпців. Якщо встановлено скалярне значення, то ширина всіх стовпців однакова. Можна передати масив з різними значеннями ширини стовпців |
# | bottom | Координати біля нижніх меж стовпців |
# | height | Послідовність значень висоти стовпців |
# | color | Колір заливання стовпців (значення або масив) |
# | edgecolor | Колір меж стовпців (значення або масив) |
# | linewidth | Значення товщини ліній ммеж стовпців в pt (значення або масив) |
# | xerr, yerr | Граничні значення для діаграм похибок (значення або масив) |
# | align | За замовчуванням значення edge визначає вирівнювання стовпців по їх лівих межах (для вертикальних стовпців) або нижніх межах (для горизонтальних стовпців). Значення center центрує стовпці по їх осях |
# | log | Якщо встановлено значення True, то використовується вісь з логарифмічною шкалою |
# | orientation | vertical (за замовчуванням) або horizontal |
# | hatch | Визначає тип штрихування стовпців: один із символів '/', '\', '|', '-', '+', 'x', 'o', 'O', '.', '* '. Повторення символу дає щільніше штрихування |

# %%
plt.bar(
    ["США", "Китай", "Японія", "Велика Британія"],
    [39, 38, 27, 22],
    color=["b", "r", "y", "g"],
)

plt.xlabel("Країна", fontsize="small", color="midnightblue")
plt.ylabel("Кількість", fontsize="small", color="midnightblue")
plt.grid()
plt.title("Золоті медалі: Літня олімпіада Токіо 2020", fontsize=15)
plt.savefig("image.png")
plt.show()

# %% [markdown]
# ### **Кругові діаграми**
#
#
# | Аргумент | Опис |
# | --- | --- |
# | colors | Послідовність специфікаторів кольору для заливання сегментів |
# | labels | Послідовність рядків написів для сегментів |
# | explode | Послідовність значень, що визначають дробову частину радіуса кругової діаграми, на яку зміщується кожен клиноподібний сегмент (0 для відсутності ефекту винесення сегмента) |
# | shadow | True або False: визначає зображення або відсутність декоративної тіні під круговою діаграмою |
# | startangle | Визначає поворот "початкової позиції" кругової діаграми на задане число градусів проти годинникової стрілки щодо горизонтальної осі. |
# | autopct | Рядок формату для підписів до сегментів: відповідні значення у відсотках або функція, що генерує необхідний рядок з даних |
# | pctdistance | Радіальне положення тексту підпису autopct щодо радіусу кругової діаграми. За замовчуванням 0.6 |
# | labeldistance | Радіальне положення тексту напису label щодо радіуса кругової діаграми. За замовчуванням 1.1 |
# | radius | Радіус кругової діаграми (за замовчуванням 1) |

# %%
labels = ["Junior Software Engineer", "Senior Software Engineer",
          "Software Engineer", "System Architect", "Technical Lead"]
data = [63, 31, 100, 2, 11]
explode = [0.15, 0, 0.15, 0, 0]

plt.pie(
    data,
    labels=labels,
    labeldistance=1.35,
    shadow=True,
    explode=explode,
    autopct="%.2f%%",
    # pctdistance=1.15,
)

plt.show()

# %% [markdown]
# ### **Діаграми в полярних координатах**

# %%
import matplotlib.pyplot as plt
import numpy as np

theta = np.linspace(0, 2.0 * np.pi, 1000)

r = np.sin(6 * theta)
plt.polar(theta, r)
plt.show()

# %% [markdown]
# ### **Тривимірні графіки**

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(projection="3d")

x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)
size = np.arange(100)

ax.scatter(x, y, z, s=size)

plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import numpy as np

gridX = np.arange(-10, 10, 0.5)
gridY = np.arange(-20, 20, 1)
x, y = np.meshgrid(gridX, gridY)
z = x ** 2 + y ** 2

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.scatter(x.reshape(-1), y.reshape(-1), z.reshape(-1))
plt.show()

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.plot_wireframe(x, y, z)
plt.show()

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.plot_surface(x, y, z)
plt.show()

# %% [markdown]
# ## **Seaborn**
#
# | Загальні параметри функцій | Опис |
# | --- | --- |
# | x, y | Пов'язують вісь x та y з конкретними ознаками з набору даних, переданого через параметр data. Дані повинні мати числовий тип. Фактично це назви стовпців із набору даних. Якщо вказати значення None, то побудова буде для всіх наборів відразу. |
# | data | Набір даних у форматі pandas.DataFrame, у якому стовпці - це імена змінних, рядки - їх значення. |
# | ci | Чисельно визначає розмір довірчого інтервалу, що відображається. Якщо присвоїти 'sd', то використовує стандартне відхилення. Щоб не відображати, присвоїти None. |
# | hue | Ім'я стовпця з набору data, який задає ознаку в наборі даних для колірного поділу даних. |
# | palette | Палітра, яка буде використана для колірного поділу набору даних за значеннями ознаки, зазначеної в hue. Ім'я палітри можна вибрати відповідно до документації. |
# | hue_order | Порядок застосування кольорів для даних з набору, переданого через параметр hue. |
# | size | Ім'я стовпця з набору data, який буде використаний для поділу даних за розміром. |
# | size_order | Задає порядок розподілу товщини лінії між елементами з набору даних, заданого через параметр size. |
# | style | Ім'я стовпця з набору data, щоб задати ознаку в наборі даних, яка буде використана для поділу даних за стилем. |
# | markers | Тип маркеру. Якщо параметр дорівнює False, то маркери не використовуватимуться. |
# | style_order | Порядок застосування стилів. |

# %%
import seaborn as sns

df = sns.load_dataset("mpg")
display(df)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# style must be one of white, dark, whitegrid, darkgrid, ticks
sns.set_style("darkgrid")

# %%
sns.set_style("darkgrid")

# sns.lineplot(data=df,
#              x="mpg",
#              y="acceleration",
#              sort=True,
#              hue="origin"
#              )
# plt.show()

sns.scatterplot(data=df,
             x="mpg",
             y="acceleration",
             hue="origin"
             )
plt.show()

# %%
sns.relplot(data=df,
             x="mpg",
             y="acceleration",
             col="origin",
             kind="scatter",
             hue="cylinders"
             )
plt.show()

# %%
sns.stripplot(data=df, x='origin', y='mpg',
              hue='cylinders'
              )
plt.show()

sns.swarmplot(data=df, x='origin', y='mpg',
              hue='cylinders'
              )
plt.show()

# %%
sns.boxplot(data=df, x='origin', y='mpg',
              hue='cylinders'
              )
plt.show()

sns.violinplot(data=df, x='origin', y='mpg',
              hue='cylinders'
              )
plt.show()

sns.boxenplot(data=df, x='origin', y='mpg',
              hue='cylinders'
              )
plt.show()

# %%
sns.pointplot(data=data, x='origin', y='mpg',
              hue='cylinders'
              )
plt.show()

sns.barplot(data=data, x='origin', y='mpg',
              hue='cylinders'
              )
plt.show()

# %%
(pd.pivot_table(df,
               values="mpg",
               index="origin",
               columns="cylinders",
               aggfunc=["mean", "std"],
               fill_value=0
                )
.round(2)
.T
 .unstack()
)
# Out:
# origin    europe                            japan                          \
# cylinders      3      4      5      6    8      3      4    5      6    8
# mean         0.0  28.41  27.37  20.10  0.0  20.55  31.60  0.0  23.88  0.0
# std          0.0   6.44   8.23   7.07  0.0   2.56   5.44  0.0   4.95  0.0
#
# origin     usa
# cylinders    3      4    5      6      8
# mean       0.0  27.84  0.0  19.66  14.96
# std        0.0   4.55  0.0   3.37   2.84

# %%
sns.countplot(x="cylinders", data=df)
plt.show()

# %% [markdown]
# ### **Візуалізація моделі лінійної регресії**

# %%
sns.lmplot(x="horsepower", y="displacement",
           data=df,
           hue="origin",
           x_estimator=np.mean
           )
plt.show()

sns.regplot(x="horsepower", y="displacement",
           data=df
           )
plt.show()

# %%
sns.residplot(x="horsepower", y="displacement",
              data=df
              )
# Out:
# <Axes: xlabel='horsepower', ylabel='displacement'>

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %% [markdown]
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
sns.set_style("darkgrid",  {'axes.labelcolor':"(0.5,0.5,0)", 'axes.edgecolor':'#061358',
'xtick.color':'#0A5806'})

sns.set_context(context="notebook", font_scale=1, rc=None)

# Create a list of colors for the palette
custom_colors = ["#4E89AE", "#ED6663", "#FFA372"]
custom_colors = ["black", "green", "orange"]

# Set the custom color palette
sns.set_palette(custom_colors)

sns.lmplot(x="horsepower", y="displacement",
           data=df,
           hue="origin",
           col="origin",
           palette="deep"
           )

# %% [markdown]
# ## **Plotly**

# %%
import plotly.express as px
df = px.data.iris()
display(df.head(2))

fig = px.scatter(df, x="sepal_width", y="sepal_length",
                 color="species",
                 marginal_x="box",
                 marginal_y="box",
                 trendline="ols"
                 )

fig.update_layout(width=1000,
                  height=500)

fig.update_traces(
                marker=dict(size=12,
                            line=dict(width=2,
                                      color='DarkSlateGrey')),
                )
fig.write_html("image.html")
fig.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_matrix(df,
                        dimensions=["sepal_width", "sepal_length", "petal_width", "petal_length"],
                        color="species", hover_data=["sepal_width"],
                        )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = px.data.tips()
display(df.head(2))

fig = px.histogram(df, x="total_bill",
                  #  histnorm='probability density',
                   opacity=0.1,

                  )


fig = px.histogram(df, x="tip",
                  #  histnorm='probability density',
                   opacity=0.2,
                   )
fig.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
display(df.corr())
sns.heatmap(df.corr())
plt.show()

fig = px.imshow(df.corr())
fig.show()
# Out:
# <ipython-input-147-13067e2ad779>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
# <ipython-input-147-13067e2ad779>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <ipython-input-147-13067e2ad779>:5: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <html>
# ...
